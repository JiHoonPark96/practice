# %%
import pandas as pd
import os

def read_csv_smart(path):
    """Try multiple encodings to robustly read CSV."""
    encodings = ["utf-8-sig", "utf-8", "cp949", "latin1"]
    last_err = None
    for enc in encodings:
        try:
            return pd.read_csv(path, encoding=enc)
        except Exception as e:
            last_err = e
    raise last_err

# Folder path where all files are stored
base_folder = r"C:\Users\starw\OneDrive\바탕 화면\dta_to_csv"

# List of North America files
north_files = [
    "North America (balance sheet).csv",
    "North America (cash flow statement).csv",
    "North America (income statement).csv",
]

# Global file name
global_filename = "Global.csv"

for north_filename in north_files:
    try:
        north_path = os.path.join(base_folder, north_filename)
        global_path = os.path.join(base_folder, global_filename)

        if not os.path.exists(north_path):
            print(f"[SKIP] North file not found: {north_path}")
            continue
        if not os.path.exists(global_path):
            print(f"[ERROR] Global file not found: {global_path}")
            continue

        # Load North America file
        df_north = read_csv_smart(north_path)

        # Load Global fresh for each North file
        df_global = read_csv_smart(global_path)

        # Step 1: Get columns from North America
        north_columns = df_north.columns.tolist()

        # Step 2: Align Global to North schema
        df_global_matched = df_global.reindex(columns=north_columns)

        # Warn if some columns missing in Global
        missing_cols = [c for c in north_columns if c not in df_global.columns]
        if missing_cols:
            print(f"[WARN] Missing in Global for '{north_filename}': {missing_cols}")

        # Step 3: Append Global below North
        df_combined = pd.concat([df_north, df_global_matched], ignore_index=True)

        # Save output
        output_path = os.path.join(
            base_folder, north_filename.replace(".csv", "_with_Global.csv")
        )
        df_combined.to_csv(output_path, index=False, encoding="utf-8-sig")

        print(
            f"[OK] Created: {output_path} | North rows: {len(df_north)} "
            f"+ Global rows: {len(df_global_matched)} -> Total: {len(df_combined)}"
        )

    except Exception as e:
        print(f"[ERROR] Processing '{north_filename}': {e}")

print("[DONE] All 3 files processed.")
# Out:
# [WARN] Missing in Global for 'North America (balance sheet).csv': ['acdo', 'acodo', 'acominc', 'acoxar', 'aedi', 'aldo', 'aocidergl', 'aociother', 'aocipen', 'aocisecgl', 'aodo', 'apb', 'apc', 'arb', 'arc', 'bast', 'bkvlps', 'cb', 'ceql', 'ceqt', 'cld2', 'cld3', 'cld4', 'cld5', 'clfc', 'clfx', 'clg', 'clis', 'cll', 'cllc', 'clo', 'clrll', 'clt', 'crv', 'cstkcv', 'dclo', 'dcom', 'dcpstk', 'dcs', 'dcvsr', 'dcvsub', 'dcvt', 'dd', 'dd2', 'dd3', 'dd4', 'dd5', 'dfs', 'dlto', 'dltp', 'dltsub', 'dm', 'dn', 'dpacb', 'dpacc', 'dpacli', 'dpacls', 'dpacme', 'dpacnr', 'dpaco', 'dpacre', 'dpvieb', 'dpvio', 'dpvir', 'drc', 'drci', 'drlt', 'ds', 'dudd', 'dvpa', 'dvpibb', 'dxd2', 'dxd3', 'dxd4', 'dxd5', 'esopct', 'esopdlt', 'esopnr', 'esopr', 'esopt', 'excadj', 'fatc', 'fatn', 'fato', 'geqrv', 'govgr', 'iaeqci', 'iaeq
# [WARN] Missing in Global for 'North America (income statement).csv': ['acchg', 'amgw', 'aqa', 'aqd', 'aqeps', 'aqi', 'aqp', 'aqs', 'arce', 'arced', 'arceeps', 'balr', 'banlr', 'batr', 'bclr', 'bcltbl', 'bcnlr', 'bcrbl', 'bctbl', 'bctr', 'bltbl', 'cbi', 'cdpac', 'cgri', 'cgti', 'cgui', 'cibegni', 'cicurr', 'cidergl', 'ciother', 'cipen', 'cisecgl', 'citotal', 'cnltbl', 'cpcbl', 'cpdoi', 'cpnli', 'cppbl', 'cprei', 'cstke', 'dbi', 'diladj', 'dilavx', 'donr', 'dpret', 'dtea', 'dted', 'dteeps', 'dtep', 'dvdnp', 'dvpd', 'dvrpiv', 'emol', 'epsfi', 'epsfx', 'epspi', 'epspx', 'esub', 'fatd', 'ffo', 'gbbl', 'gdwlam', 'gdwlia', 'gdwlid', 'gdwlieps', 'gdwlip', 'gla', 'glcea', 'glced', 'glceeps', 'glcep', 'gld', 'gleps', 'glp', 'gp', 'gphbl', 'gplbl', 'gpobl', 'gprbl', 'gptbl', 'gwo', 'hedgegl', 'ibadj', 'ibbl', 'ibcom', 'ipabl', 'iphbl', 'iplbl', 'ipobl', 'iptbl', 'irei', 'irent', 'irii', 'irli', 'irnli', 'irsi', 'itci', 'li', 'llrci', 'llrcr', 'llwoci', 'llwocr', 'lst', 'nco', 'nfsr', 'ni', 'niadj', 'nieci', 'niint', 'niit', 'nim', 'nits', 'nopio', 'nrtxt', 'nrtxtd', 'nrtxteps', 'opeps', 'opili', 'opincar', 'opini', 'opioi', 'opiri', 'opiti', 'oprepsx', 'palr', 'panlr', 'patr', 'pclr', 'pcnlr', 'pctr', 'pidom', 'pifo', 'pll', 'pltbl', 'pnca', 'pncad', 'pncaeps', 'pncia', 'pncid', 'pncieps', 'pncip', 'pncwia', 'pncwid', 'pncwieps', 'pncwip', 'pnlbl', 'pnli', 'pobl', 'ppcbl', 'pppabl', 'ppphbl', 'pppobl', 'ppptbl', 'prca', 'prcad', 'prcaeps', 'prebl', 'pri', 'ptbl', 'pvo', 'pwoi', 'rca', 'rcd', 'rceps', 'rcp', 'rdip', 'rdipa', 'rdipd', 'rdipeps', 'rmum', 'rra', 'rrd', 'rrp', 'seta', 'setd', 'seteps', 'setp', 'spce', 'spced', 'spceeps', 'spid', 'spieps', 'spioa', 'spiop', 'sret', 'stkco', 'stkcpa', 'tf', 'tie', 'tii', 'txdfed', 'txdfo', 'txds', 'txeqa', 'txeqii', 'txfed', 'txfo', 'txs', 'txva', 'udpfa', 'udvp', 'ugi', 'uniami', 'unopinc', 'uopi', 'updvp', 'uspi', 'usubdvp', 'utme', 'utxfed', 'uxinst', 'uxintd', 'wda', 'wdd', 'wdeps', 'wdp', 'xad', 'xdepl', 'xdp', 'xintopt', 'xnbi', 'xnf', 'xnins', 'xoprar', 'xoptd', 'xopteps', 'xuw', 'xuwli', 'xuwnli', 'xuwoi', 'xuwrei', 'xuwti']
# [OK] Created: C:\Users\starw\OneDrive\바탕 화면\dta_to_csv\North America (income statement)_with_Global.csv | North rows: 304117 + Global rows: 776184 -> Total: 1080301
# [DONE] All 3 files processed.

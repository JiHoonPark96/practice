# %%
import pandas as pd
from pathlib import Path

# ===== 사용자 경로 지정 =====
ROOT_DIR = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta\Rogall_2021_Data")
OUTPUT_FILE = ROOT_DIR / "Rogall_variable_map_with_transform.xlsx"
# ==========================

# 변환변수 ↔ 원시변수 ↔ 변환 방식
TRANSFORM_MAP = {
    "lcat2_pcT": ("cat2_pcT", "log(x)"),
    "lkigali_dis2": ("kigali_dis2", "log(x)"),
    "lborder_dis2": ("border_dis2", "log(x)"),
    "ltutsi_dis2": ("tutsi_dis2", "log(x)"),
    "lmaincity_dis2": ("maincity_dis2", "log(x)"),
    "lpopdens": ("popdens", "log(x)"),
    "larea": ("area", "log(x)"),
    "LT_trans": ("T_trans", "log(x)")
}

results = []

for f in ROOT_DIR.rglob("*.dta"):
    try:
        df = pd.read_stata(f, convert_categoricals=False)
        variables = df.columns.tolist()

        for transformed, (original, transform_rule) in TRANSFORM_MAP.items():
            for var in variables:
                if original.lower() == var.lower():
                    results.append({
                        "File": f.name,
                        "Folder": str(f.parent),
                        "Transformed Variable": transformed,
                        "Original Variable": var,
                        "Transformation": transform_rule
                    })
    except Exception as e:
        print(f"[WARN] {f} 읽기 실패: {e}")

# 결과 저장
df_out = pd.DataFrame(results)
if not df_out.empty:
    df_out.to_excel(OUTPUT_FILE, index=False)
    print(f"[DONE] Rogall (2021) 변수 매핑+변환 저장 완료 → {OUTPUT_FILE}")
else:
    print("[INFO] 매칭된 원시 변수를 찾지 못했습니다.")
# Out:
# C:\Users\starw\AppData\Local\Temp\ipykernel_23256\1412736551.py:25: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   df = pd.read_stata(f, convert_categoricals=False)
# [DONE] Rogall (2021) 변수 매핑+변환 저장 완료 → C:\Users\starw\OneDrive\바탕 화면\dta\Rogall_2021_Data\Rogall_variable_map_with_transform.xlsx

# %%
import pandas as pd
from pathlib import Path

# ===== 사용자 경로 지정 =====
ROOT_DIR = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta\Carranza_et_al_2022_Data")
OUTPUT_FILE = ROOT_DIR / "Carranza_variable_map_with_transform.xlsx"
# ==========================

# Carranza 논문 코드에서 실제 사용된 변환변수 ↔ 원시변수 ↔ 변환방식
TRANSFORM_MAP = {
    "el_emp_hour_all_uncd_i": ("emp_hour_all_uncd_i", "normalized employment hours")
}

results = []

for f in ROOT_DIR.rglob("*.dta"):
    try:
        df = pd.read_stata(f, convert_categoricals=False)
        variables = df.columns.tolist()

        for transformed, (original, transform_rule) in TRANSFORM_MAP.items():
            for var in variables:
                if original.lower() == var.lower():
                    results.append({
                        "File": f.name,
                        "Folder": str(f.parent),
                        "Transformed Variable": transformed,
                        "Original Variable": var,
                        "Transformation": transform_rule
                    })
    except Exception as e:
        print(f"[WARN] {f} 읽기 실패: {e}")

# 결과 저장
df_out = pd.DataFrame(results)
if not df_out.empty:
    df_out.to_excel(OUTPUT_FILE, index=False)
    print(f"[DONE] Carranza (2022) 변수 매핑+변환 저장 완료 → {OUTPUT_FILE}")
else:
    print("[INFO] 매칭된 원시 변수를 찾지 못했습니다.")
# Out:
# [INFO] 매칭된 원시 변수를 찾지 못했습니다.

# %%
import pandas as pd
from pathlib import Path

# ===== 사용자 경로 지정 =====
ROOT_DIR = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta\Johnson_2020_Data")
OUTPUT_FILE = ROOT_DIR / "Johnson_variable_map_with_transform.xlsx"
# ==========================

# Johnson 논문 코드에서 실제 사용된 변환변수 ↔ 원시변수 ↔ 변환방식
TRANSFORM_MAP = {
    "arcsinh_var": ("penalty", "asinh(penalty)")
}

results = []

for f in ROOT_DIR.rglob("*.dta"):
    try:
        df = pd.read_stata(f, convert_categoricals=False)
        variables = df.columns.tolist()

        for transformed, (original, transform_rule) in TRANSFORM_MAP.items():
            for var in variables:
                if original.lower() == var.lower():
                    results.append({
                        "File": f.name,
                        "Folder": str(f.parent),
                        "Transformed Variable": transformed,
                        "Original Variable": var,
                        "Transformation": transform_rule
                    })
    except Exception as e:
        print(f"[WARN] {f} 읽기 실패: {e}")

# 결과 저장
df_out = pd.DataFrame(results)
if not df_out.empty:
    df_out.to_excel(OUTPUT_FILE, index=False)
    print(f"[DONE] Johnson (2020) 변수 매핑+변환 저장 완료 → {OUTPUT_FILE}")
else:
    print("[INFO] 매칭된 원시 변수를 찾지 못했습니다.")
# Out:
# [INFO] 매칭된 원시 변수를 찾지 못했습니다.

# %%
import pandas as pd
from pathlib import Path

# ===== 사용자 경로 지정 =====
ROOT_DIR = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta\Azoulay_et_al_2019_Data")
OUTPUT_FILE = ROOT_DIR / "Azoulay_variable_map_with_transform.xlsx"
# ==========================

# Azoulay 논문 코드에서 실제 사용된 변환변수 ↔ 원시변수 ↔ 변환방식
TRANSFORM_MAP = {
    "ihs_prox_0_ncoauth": ("prox_0_ncoauth", "asinh(prox_0_ncoauth)")
}

results = []

for f in ROOT_DIR.rglob("*.dta"):
    try:
        df = pd.read_stata(f, convert_categoricals=False)
        variables = df.columns.tolist()

        for transformed, (original, transform_rule) in TRANSFORM_MAP.items():
            for var in variables:
                if original.lower() == var.lower():
                    results.append({
                        "File": f.name,
                        "Folder": str(f.parent),
                        "Transformed Variable": transformed,
                        "Original Variable": var,
                        "Transformation": transform_rule
                    })
    except Exception as e:
        print(f"[WARN] {f} 읽기 실패: {e}")

# 결과 저장
df_out = pd.DataFrame(results)
if not df_out.empty:
    df_out.to_excel(OUTPUT_FILE, index=False)
    print(f"[DONE] Azoulay (2019) 변수 매핑+변환 저장 완료 → {OUTPUT_FILE}")
else:
    print("[INFO] 매칭된 원시 변수를 찾지 못했습니다.")
# Out:
# C:\Users\starw\AppData\Local\Temp\ipykernel_23256\1961165029.py:18: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   df = pd.read_stata(f, convert_categoricals=False)
# [INFO] 매칭된 원시 변수를 찾지 못했습니다.

# %%
import pandas as pd
from pathlib import Path

# ===== 사용자 경로 지정 =====
ROOT_DIR = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta\Cao_and_Chen_2022_Data")
OUTPUT_FILE = ROOT_DIR / "CaoChen_variable_map_with_transform.xlsx"
# ==========================

# Cao & Chen 논문 코드에서 실제 사용된 변환변수 ↔ 원시변수 ↔ 변환방식
TRANSFORM_MAP = {
    "ashonset_cntypop1600": ("honset_cntypop1600", "asinh(honset_cntypop1600)")
}

results = []

for f in ROOT_DIR.rglob("*.dta"):
    try:
        df = pd.read_stata(f, convert_categoricals=False)
        variables = df.columns.tolist()

        for transformed, (original, transform_rule) in TRANSFORM_MAP.items():
            for var in variables:
                if original.lower() == var.lower():
                    results.append({
                        "File": f.name,
                        "Folder": str(f.parent),
                        "Transformed Variable": transformed,
                        "Original Variable": var,
                        "Transformation": transform_rule
                    })
    except Exception as e:
        print(f"[WARN] {f} 읽기 실패: {e}")

# 결과 저장
df_out = pd.DataFrame(results)
if not df_out.empty:
    df_out.to_excel(OUTPUT_FILE, index=False)
    print(f"[DONE] Cao & Chen (2022) 변수 매핑+변환 저장 완료 → {OUTPUT_FILE}")
else:
    print("[INFO] 매칭된 원시 변수를 찾지 못했습니다.")
# Out:
# [INFO] 매칭된 원시 변수를 찾지 못했습니다.

# %%
import pandas as pd
from pathlib import Path

# ===== 사용자 경로 지정 =====
ROOT_DIR = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta\Arora_et_al_2021_Data")
OUTPUT_FILE = ROOT_DIR / "Arora_variable_map_with_transform.xlsx"
# ==========================

# Arora et al. 논문 코드에서 실제 사용된 변환변수 ↔ 원시변수 ↔ 변환방식
TRANSFORM_MAP = {
    "asinh_pub_yr": ("pub_yr", "asinh(pub_yr)")
}

results = []

for f in ROOT_DIR.rglob("*.dta"):
    try:
        df = pd.read_stata(f, convert_categoricals=False)
        variables = df.columns.tolist()

        for transformed, (original, transform_rule) in TRANSFORM_MAP.items():
            for var in variables:
                if original.lower() == var.lower():
                    results.append({
                        "File": f.name,
                        "Folder": str(f.parent),
                        "Transformed Variable": transformed,
                        "Original Variable": var,
                        "Transformation": transform_rule
                    })
    except Exception as e:
        print(f"[WARN] {f} 읽기 실패: {e}")

# 결과 저장
df_out = pd.DataFrame(results)
if not df_out.empty:
    df_out.to_excel(OUTPUT_FILE, index=False)
    print(f"[DONE] Arora et al. (2021) 변수 매핑+변환 저장 완료 → {OUTPUT_FILE}")
else:
    print("[INFO] 매칭된 원시 변수를 찾지 못했습니다.")
# Out:
# [DONE] Arora et al. (2021) 변수 매핑+변환 저장 완료 → C:\Users\starw\OneDrive\바탕 화면\dta\Arora_et_al_2021_Data\Arora_variable_map_with_transform.xlsx

# %%
import pandas as pd
from pathlib import Path

# ===== 사용자 경로 지정 =====
ROOT_DIR = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta\Fetzer_et_al_2021_Data")
OUTPUT_FILE = ROOT_DIR / "Fetzer_variable_map_with_transform.xlsx"
# ==========================

# Fetzer et al. 논문 코드에서 실제 사용된 변환변수 ↔ 원시변수 ↔ 변환방식
TRANSFORM_MAP = {
    "asinhtotalov": ("totalov", "asinh(totalov)")
}

results = []

for f in ROOT_DIR.rglob("*.dta"):
    try:
        df = pd.read_stata(f, convert_categoricals=False)
        variables = df.columns.tolist()

        for transformed, (original, transform_rule) in TRANSFORM_MAP.items():
            for var in variables:
                if original.lower() == var.lower():
                    results.append({
                        "File": f.name,
                        "Folder": str(f.parent),
                        "Transformed Variable": transformed,
                        "Original Variable": var,
                        "Transformation": transform_rule
                    })
    except Exception as e:
        print(f"[WARN] {f} 읽기 실패: {e}")

# 결과 저장
df_out = pd.DataFrame(results)
if not df_out.empty:
    df_out.to_excel(OUTPUT_FILE, index=False)
    print(f"[DONE] Fetzer et al. (2021) 변수 매핑+변환 저장 완료 → {OUTPUT_FILE}")
else:
    print("[INFO] 매칭된 원시 변수를 찾지 못했습니다.")
# Out:
# [WARN] C:\Users\starw\OneDrive\바탕 화면\dta\Fetzer_et_al_2021_Data\REPOSITORY\PROCESSING_FILES\DATA_INPUTS\DEPLOYMENT\ISAFSTRENGTH.dta 읽기 실패: Version of given Stata file is 110. pandas supports importing versions 105, 108, 111 (Stata 7SE), 113 (Stata 8/9), 114 (Stata 10/11), 115 (Stata 12), 117 (Stata 13), 118 (Stata 14/15/16),and 119 (Stata 15/16, over 32,767 variables).
# [WARN] C:\Users\starw\OneDrive\바탕 화면\dta\Fetzer_et_al_2021_Data\REPOSITORY\PROCESSING_FILES\DATA_INPUTS\DISTANCE_MEASURES\NEARROADS.dta 읽기 실패: Version of given Stata file is 110. pandas supports importing versions 105, 108, 111 (Stata 7SE), 113 (Stata 8/9), 114 (Stata 10/11), 115 (Stata 12), 117 (Stata 13), 118 (Stata 14/15/16),and 119 (Stata 15/16, over 32,767 variables).
# [WARN] C:\Users\starw\OneDrive\바탕 화면\dta\Fetzer_et_al_2021_Data\REPOSITORY\PROCESSING_FILES\DATA_INPUTS\DISTANCE_MEASURES\TRAVELDISTNEARMILAIRPORT.dta 읽기 실패: Version of given Stata file is 110. pandas supports importing versions 105, 108, 111 (Stata 7SE), 113 (Stata 8/9), 114 (Stata 10/11), 115 (Stata 12), 117 (Stata 13), 118 (Stata 14/15/16),and 119 (Stata 15/16, over 32,767 variables).
# [DONE] Fetzer et al. (2021) 변수 매핑+변환 저장 완료 → C:\Users\starw\OneDrive\바탕 화면\dta\Fetzer_et_al_2021_Data\Fetzer_variable_map_with_transform.xlsx

# %%
import pandas as pd
from pathlib import Path

# ===== 사용자 경로 지정 =====
ROOT_DIR = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta\Moretti_2021_Data")
OUTPUT_FILE = ROOT_DIR / "Moretti_variable_map_with_transform.xlsx"
# ==========================

# Moretti (2021) 논문 코드에서 실제 사용된 변환변수 ↔ 원시변수 ↔ 변환방식
TRANSFORM_MAP = {
    "y": ("y", "None"),
    "x": ("x", "None")
}

results = []

for f in ROOT_DIR.rglob("*.dta"):
    try:
        df = pd.read_stata(f, convert_categoricals=False)
        variables = df.columns.tolist()

        for transformed, (original, transform_rule) in TRANSFORM_MAP.items():
            for var in variables:
                if original.lower() == var.lower():
                    results.append({
                        "File": f.name,
                        "Folder": str(f.parent),
                        "Transformed Variable": transformed,
                        "Original Variable": var,
                        "Transformation": transform_rule
                    })
    except Exception as e:
        print(f"[WARN] {f} 읽기 실패: {e}")

# 결과 저장
df_out = pd.DataFrame(results)
if not df_out.empty:
    df_out.to_excel(OUTPUT_FILE, index=False)
    print(f"[DONE] Moretti (2021) 변수 매핑+변환 저장 완료 → {OUTPUT_FILE}")
else:
    print("[INFO] 매칭된 원시 변수를 찾지 못했습니다.")
# Out:
# [INFO] 매칭된 원시 변수를 찾지 못했습니다.

# %%
import pandas as pd
from pathlib import Path

# ===== 사용자 경로 지정 =====
ROOT_DIR = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta\Berkouwer_and_Dean_2022_Data")
OUTPUT_FILE = ROOT_DIR / "Berkouwer_Dean_variable_map_with_transform.xlsx"
# ==========================

# 논문 코드에서 사용된 변환변수 ↔ 원시변수 ↔ 변환방식
TRANSFORM_MAP = {
    "ihs_amount_weekly": ("amount_weekly", "asinh(amount_weekly)")
}

results = []

for f in ROOT_DIR.rglob("*.dta"):
    try:
        df = pd.read_stata(f, convert_categoricals=False)
        variables = df.columns.tolist()

        for transformed, (original, transform_rule) in TRANSFORM_MAP.items():
            for var in variables:
                if original.lower() == var.lower():
                    results.append({
                        "File": f.name,
                        "Folder": str(f.parent),
                        "Transformed Variable": transformed,
                        "Original Variable": var,
                        "Transformation": transform_rule
                    })
    except Exception as e:
        print(f"[WARN] {f} 읽기 실패: {e}")

# 결과 저장
df_out = pd.DataFrame(results)
if not df_out.empty:
    df_out.to_excel(OUTPUT_FILE, index=False)
    print(f"[DONE] Berkouwer & Dean (2022) 변수 매핑+변환 저장 완료 → {OUTPUT_FILE}")
else:
    print("[INFO] 매칭된 원시 변수를 찾지 못했습니다.")
# Out:
# [DONE] Berkouwer & Dean (2022) 변수 매핑+변환 저장 완료 → C:\Users\starw\OneDrive\바탕 화면\dta\Berkouwer_and_Dean_2022_Data\Berkouwer_Dean_variable_map_with_transform.xlsx

# %%
import pandas as pd
from pathlib import Path

# ===== 사용자 경로 =====
FOLDER = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta\Hjort_and_Poulsen_2019_Data")
OUTPUT_FILE = FOLDER / "Hjort_Poulsen_variable_map_with_transform.xlsx"
# ======================

# 이 논문에서 추적할 변환 변수
TRANSFORM_MAP = {
    "loginternet": {"original": ["internet"], "transformation": "log(1+internet)"}
}

results = []

# dta 파일 전체 탐색
for f in FOLDER.rglob("*.dta"):
    try:
        df = pd.read_stata(f, convert_categoricals=False)
        cols = [c.lower() for c in df.columns]  # 소문자로 통일
        for tvar, info in TRANSFORM_MAP.items():
            for orig in info["original"]:
                if orig.lower() in cols:
                    results.append({
                        "Transformed Variable": tvar,
                        "Original Variable": orig,
                        "Transformation": info["transformation"],
                        "File": f.name,
                        "Folder": str(f.parent)
                    })
    except Exception as e:
        print(f"[WARN] {f} 읽기 실패: {e}")

# 결과 저장
if results:
    df_out = pd.DataFrame(results)
    df_out.to_excel(OUTPUT_FILE, index=False)
    print(f"[DONE] 결과 저장 완료 → {OUTPUT_FILE}")
else:
    print("[INFO] 매칭된 변수를 찾지 못했습니다.")
# Out:
# [DONE] 결과 저장 완료 → C:\Users\starw\OneDrive\바탕 화면\dta\Hjort_and_Poulsen_2019_Data\Hjort_Poulsen_variable_map_with_transform.xlsx

# %%
import pandas as pd
from pathlib import Path

# ===== 사용자 경로 (각 논문별 결과 저장된 폴더) =====
ROOT_DIR = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta")
OUTPUT_FILE = ROOT_DIR / "All_Papers_Variable_Transform_Map.xlsx"
# ============================================

# 논문별 결과 파일 리스트 (이미 저장된 엑셀들)
file_list = [
    "Hjort_Poulsen_variable_map_with_transform.xlsx",
    "Rogall_variable_map_with_transform.xlsx",
    "Carranza_variable_map_with_transform.xlsx",
    "Johnson_variable_map_with_transform.xlsx",
    "Azoulay_variable_map_with_transform.xlsx",
    "Cao_Chen_variable_map_with_transform.xlsx",
    "Arora_variable_map_with_transform.xlsx",
    "Fetzer_variable_map_with_transform.xlsx",
    "Moretti_variable_map_with_transform.xlsx",
    "Berkouwer_Dean_variable_map_with_transform.xlsx"
]

all_dfs = []
for fname in file_list:
    fpath = ROOT_DIR.rglob(fname)  # 하위폴더까지 탐색
    for f in fpath:
        try:
            df = pd.read_excel(f)
            df.insert(0, "Paper", fname.replace("_variable_map_with_transform.xlsx", ""))
            all_dfs.append(df)
        except Exception as e:
            print(f"[WARN] {fname} 읽기 실패: {e}")

if all_dfs:
    final_df = pd.concat(all_dfs, ignore_index=True)
    final_df.to_excel(OUTPUT_FILE, index=False)
    print(f"[DONE] 통합 엑셀 저장 완료 → {OUTPUT_FILE}")
else:
    print("[INFO] 통합할 데이터가 없습니다.")
# Out:
# [DONE] 통합 엑셀 저장 완료 → C:\Users\starw\OneDrive\바탕 화면\dta\All_Papers_Variable_Transform_Map.xlsx

# %%
import pandas as pd
from pathlib import Path

# ===== 사용자 상위 폴더 (모든 논문 Data 폴더가 들어있는 곳) =====
ROOT_DIR = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta")

# ===== Appendix 변환 변수 리스트 (남은 5개만) =====
TRANSFORMED_VARS = {
    "Carranza_et_al_2022_Data": ["el_emp_hour_all_uncd_i"],
    "Johnson_2020_Data": ["arcsinh_var"],
    "Azoulay_et_al_2019_Data": ["ihs_prox_0_ncoauth"],
    "Cao_and_Chen_2022_Data": ["ashonset_cntypop1600"],
    "Moretti_2021_Data": ["y", "x"]
}

# ===== 변환 변수 → 원시 변수 후보 규칙 =====
def guess_original(varname: str):
    v = varname.lower()
    for prefix in ["log", "asinh", "ihs", "l"]:
        if v.startswith(prefix) and len(v) > len(prefix) + 2:
            return v[len(prefix):]  # 접두사 제거
    return None  # 못 찾으면 None

results = []

# ===== 폴더 순회 =====
for folder, tvars in TRANSFORMED_VARS.items():
    folder_path = ROOT_DIR / folder
    if not folder_path.exists():
        print(f"[SKIP] {folder} 폴더 없음")
        continue

    print(f"\n▶ {folder} 탐색 중...")

    for f in folder_path.rglob("*.dta"):
        try:
            df = pd.read_stata(f, convert_categoricals=False)
            cols = [c.lower() for c in df.columns]

            for tvar in tvars:
                orig_guess = guess_original(tvar)
                if orig_guess and orig_guess in cols:
                    results.append({
                        "Paper": folder,
                        "Transformed Variable": tvar,
                        "Original Variable Candidate": orig_guess,
                        "File": f.name
                    })

        except Exception as e:
            print(f"[WARN] {f.name} 읽기 실패: {e}")

# ===== 결과 저장 =====
if results:
    df_out = pd.DataFrame(results)
    output_file = ROOT_DIR / "remaining5_papers_original_candidates.xlsx"
    df_out.to_excel(output_file, index=False)
    print(f"\n[DONE] 결과 저장 완료 → {output_file}")
else:
    print("\n[INFO] 원시 변수 후보를 찾지 못했습니다.")
# Out:
# ▶ Carranza_et_al_2022_Data 탐색 중...
#
# ▶ Johnson_2020_Data 탐색 중...
#
# ▶ Azoulay_et_al_2019_Data 탐색 중...
# C:\Users\starw\AppData\Local\Temp\ipykernel_23256\1797846133.py:37: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   df = pd.read_stata(f, convert_categoricals=False)
# ▶ Cao_and_Chen_2022_Data 탐색 중...
#
# ▶ Moretti_2021_Data 탐색 중...
#
# [INFO] 원시 변수 후보를 찾지 못했습니다.

# %%
import pandas as pd
from pathlib import Path

# ===== 상위 경로 (논문별 Data 폴더들이 여기에 있음) =====
ROOT_DIR = Path(r"C:\Users\starw\OneDrive\바탕 화면\dta")

# ===== Appendix에서 확인한 변환 변수 ↔ 원시 변수 키워드 =====
SEARCH_KEYWORDS = {
    "Carranza_et_al_2022_Data": ["emp", "hour", "work", "employment"],
    "Johnson_2020_Data": ["penalty", "fine", "violation", "osha", "var"],
    "Azoulay_et_al_2019_Data": ["prox", "ncoauth", "coauthor"],
    "Cao_and_Chen_2022_Data": ["onset", "conflict", "cntypop", "1600"],
    "Moretti_2021_Data": ["prod", "productivity", "cluster", "inv", "y", "x"]
}

results = []

# ===== 각 논문 폴더 탐색 =====
for folder, keywords in SEARCH_KEYWORDS.items():
    folder_path = ROOT_DIR / folder
    if not folder_path.exists():
        print(f"[SKIP] {folder} 폴더 없음")
        continue

    print(f"\n▶ {folder} 탐색 중...")

    for f in folder_path.rglob("*.dta"):
        try:
            df = pd.read_stata(f, convert_categoricals=False)
            cols = df.columns.tolist()

            # 키워드가 들어간 변수명만 추출
            matches = [c for c in cols if any(kw in c.lower() for kw in keywords)]
            if matches:
                results.append({
                    "Paper": folder,
                    "File": f.name,
                    "Matched Variables": ", ".join(matches)
                })
                print(f"  📂 {f.name} → {matches}")

        except Exception as e:
            print(f"[WARN] {f.name} 읽기 실패: {e}")

# ===== 결과 저장 =====
if results:
    df_out = pd.DataFrame(results)
    output_file = ROOT_DIR / "remaining5_manual_search.xlsx"
    df_out.to_excel(output_file, index=False)
    print(f"\n[DONE] 결과 저장 완료 → {output_file}")
else:
    print("\n[INFO] 키워드 기반 매칭 결과가 없습니다.")
# Out:
# ▶ Carranza_et_al_2022_Data 탐색 중...
#   📂 audit_data.dta → ['emp_ever', 'bl_emp_7d']
#   📂 firm_data_clean.dta → ['employee_total', 'employee_entry_total', 'employee_pay', 'employee_entry_total_miss', 'employee_pay_miss']
#   📂 firm_data_trimmed.dta → ['employee_total', 'employee_entry_total', 'employee_pay']
#   📂 wsdata_cleaned_signalling.dta → ['bl_emp_7d', 'bl_emp_earn_all', 'bl_search_hour', 'el_emp_m1', 'el_emp_m2', 'el_emp_m3', 'el_emp_7d', 'el_emp_recruit_7d', 'el_emp_hour_all', 'el_search_hour_7d', 'bl_dem_hhemp', 'bl_emp_earn_all_uncd', 'bl_everwork1', 'bl_everwork3', 'el_emp_7dtype_wrperm', 'el_emp_7dtype_wr_uncd', 'el_emp_earn_all', 'el_emp_wage_all', 'el_emp_dur', 'el_emp_earn_all_uncd_i', 'el_emp_hour_all_uncd_i', 'el_emp_wage_all_uncd_i', 'el_search_hour_i', 'el_emp_dur_cens', 'el_emp_type_wage', 'el_emp_type_wage_uncd', 'el_emp_type_self', 'el_emp_type_self_uncd', 'bl_emp_earn_all_uncd_md', 'bl_emp_earn_all_uncd_nm']
#   📂 wsdata_signalling_interim.dta → ['bl_demo_hh_employed', 'bl_work_history', 'bl_work_week', 'bl_work_earnings', 'bl_work_hours', 'bl_search_hours', 'el_work_month1_a', 'el_work_month2_a', 'el_work_month3_a', 'el_work_employed_a', 'el_work_started_7d_a', 'el_work_agreement_7d_a', 'el_work_employees_7d_a', 'el_work_transport_7d_mode_a', 'el_work_transport_7d_a', 'el_work_transport_cost_7d_a', 'el_work_payment_a', 'el_work_earnings_7d_a_v1', 'el_work_earnings_7d_a', 'el_work_earnings_7d_a_2', 'el_work_earnings_bands_7d_a', 'el_work_hours_7d_a', 'el_work_dissatisfied_7d_a', 'el_work_future_7d_a', 'el_work_recruited_7d_a', 'el_worked_firm_consent_a', 'el_work_earnings_a_v1', 'el_work_earnings_a', 'el_work_earnings_bands_a', 'el_work_hours_a', 'el_work_agreement_m_a', 'el_work_started_m_a', 'el_work_ended_m_a', 'el_work_employees_m_a', 'el_work_transport_mode_m_a', 'el_work_transport_m_a', 'el_work_transport_cost_m_a', 'el_work_recruited_m_a', 'el_work_payment_m_a', 'el_work_income_a', 'el_work_income_piece_a', 'el_work_hours_7d_2a', 'el_time_work_a', 'el_search_hours_7d_a', 'el_search_network_7d_a', 'el_search_workareas_7d_a', 'el_search_hours_m_a', 'el_search_network_m_a', 'el_search_workareas_m_a', 'el_search_hours_7d_b', 'el_search_network_7d_b', 'el_search_workareas_7d_b', 'el_search_hours_m_b', 'el_search_network_m_b', 'el_search_workareas_m_b', 'el_work_month1_b', 'el_work_month2_b', 'el_work_month3_b', 'el_work_employed_b', 'el_work_agreement_7d_b', 'el_work_started_7d_b', 'el_work_employees_7d_b', 'el_work_transport_7d_mode_b', 'el_work_transport_7d_b', 'el_work_transport_cost_7d_b', 'el_work_payment_b', 'el_work_earnings_7d_b_v1', 'el_work_earnings_7d_b', 'el_work_earnings_7d_b_2', 'el_work_earnings_bands_7d_b', 'el_work_hours_7d_b', 'el_work_dissatisfied_7d_b', 'el_work_future_7d_b', 'el_work_recruited_7d_b', 'el_worked_firm_consent_b', 'el_work_agreement_m_b', 'el_work_started_m_b', 'el_work_ended_m_b', 'el_work_employees_m_b', 'el_work_transport_mode_m_b', 'el_work_transport_m_b', 'el_work_transport_cost_m_b', 'el_work_recruited_m_b', 'el_work_payment_m_b', 'el_work_income_b', 'el_work_income_piece_b', 'el_work_hours_7d_2b', 'el_work_earnings_b_v1', 'el_work_earnings_b', 'el_work_earnings_bands_b', 'el_work_hours_b', 'el_time_work_b', 'el_work_earnings_incorrect_a', 'el_work_earnings_incorrect_7d_a', 'el_work_earnings_incorrect_b', 'el_work_earnings_incorrect_7d_b', 'el_work_earnings_hours_a', 'el_work_earnings_days_a', 'el_work_earnings_2weeks_a', 'el_work_earnings_month_a', 'el_work_earnings_wrong_7d_a_2', 'el_work_hours_incorrect_7d_2a', 'el_work_earnings_hours_b', 'el_work_earnings_days_b', 'el_work_earnings_2weeks_b', 'el_work_earnings_month_b', 'el_work_earnings_wrong_7d_b_2', 'el_work_hours_incorrect_7d_2b', 'el_work_transport_costnote_7d_a', 'el_work_transport_costnote_7d_b', 'el_worked_a_intro', 'el_worked_b_intro', 'el_work_transport_mode_b']
#   📂 wsdata_signalling_interim_all.dta → ['bl_emp_7d', 'bl_emp_earn_all', 'bl_search_hour', 'el_emp_m1', 'el_emp_m2', 'el_emp_m3', 'el_emp_7d', 'el_emp_recruit_7d', 'el_emp_hour_all', 'el_search_hour_7d', 'bl_dem_hhemp', 'bl_emp_earn_all_uncd', 'bl_everwork1', 'bl_everwork3', 'el_emp_7dtype_wrperm', 'el_emp_7dtype_wr_uncd', 'el_emp_earn_all', 'el_emp_wage_all', 'el_emp_dur', 'el_emp_earn_all_uncd_i', 'el_emp_hour_all_uncd_i', 'el_emp_wage_all_uncd_i', 'el_search_hour_i', 'el_emp_dur_cens', 'el_emp_type_wage', 'el_emp_type_wage_uncd', 'el_emp_type_self', 'el_emp_type_self_uncd']
#   📂 wsdata_signalling_interim_bl.dta → ['bl_demo_hh_employed', 'bl_emp_history', 'bl_emp_7d', 'bl_emp_earn_all', 'bl_emp_hour_all', 'bl_search_hour', 'el_work_month1_a', 'el_work_month2_a', 'el_work_month3_a', 'el_work_employed_a', 'el_work_started_7d_a', 'el_work_agreement_7d_a', 'el_work_employees_7d_a', 'el_work_transport_7d_mode_a', 'el_work_transport_7d_a', 'el_work_transport_cost_7d_a', 'el_work_payment_a', 'el_work_earnings_7d_a_v1', 'el_work_earnings_7d_a', 'el_work_earnings_7d_a_2', 'el_work_earnings_bands_7d_a', 'el_work_hours_7d_a', 'el_work_dissatisfied_7d_a', 'el_work_future_7d_a', 'el_work_recruited_7d_a', 'el_worked_firm_consent_a', 'el_work_earnings_a_v1', 'el_work_earnings_a', 'el_work_earnings_bands_a', 'el_work_hours_a', 'el_work_agreement_m_a', 'el_work_started_m_a', 'el_work_ended_m_a', 'el_work_employees_m_a', 'el_work_transport_mode_m_a', 'el_work_transport_m_a', 'el_work_transport_cost_m_a', 'el_work_recruited_m_a', 'el_work_payment_m_a', 'el_work_income_a', 'el_work_income_piece_a', 'el_work_hours_7d_2a', 'el_time_work_a', 'el_search_hours_7d_a', 'el_search_network_7d_a', 'el_search_workareas_7d_a', 'el_search_hours_m_a', 'el_search_network_m_a', 'el_search_workareas_m_a', 'el_search_hours_7d_b', 'el_search_network_7d_b', 'el_search_workareas_7d_b', 'el_search_hours_m_b', 'el_search_network_m_b', 'el_search_workareas_m_b', 'el_work_month1_b', 'el_work_month2_b', 'el_work_month3_b', 'el_work_employed_b', 'el_work_agreement_7d_b', 'el_work_started_7d_b', 'el_work_employees_7d_b', 'el_work_transport_7d_mode_b', 'el_work_transport_7d_b', 'el_work_transport_cost_7d_b', 'el_work_payment_b', 'el_work_earnings_7d_b_v1', 'el_work_earnings_7d_b', 'el_work_earnings_7d_b_2', 'el_work_earnings_bands_7d_b', 'el_work_hours_7d_b', 'el_work_dissatisfied_7d_b', 'el_work_future_7d_b', 'el_work_recruited_7d_b', 'el_worked_firm_consent_b', 'el_work_agreement_m_b', 'el_work_started_m_b', 'el_work_ended_m_b', 'el_work_employees_m_b', 'el_work_transport_mode_m_b', 'el_work_transport_m_b', 'el_work_transport_cost_m_b', 'el_work_recruited_m_b', 'el_work_payment_m_b', 'el_work_income_b', 'el_work_income_piece_b', 'el_work_hours_7d_2b', 'el_work_earnings_b_v1', 'el_work_earnings_b', 'el_work_earnings_bands_b', 'el_work_hours_b', 'el_time_work_b', 'el_work_earnings_incorrect_a', 'el_work_earnings_incorrect_7d_a', 'el_work_earnings_incorrect_b', 'el_work_earnings_incorrect_7d_b', 'el_work_earnings_hours_a', 'el_work_earnings_days_a', 'el_work_earnings_2weeks_a', 'el_work_earnings_month_a', 'el_work_earnings_wrong_7d_a_2', 'el_work_hours_incorrect_7d_2a', 'el_work_earnings_hours_b', 'el_work_earnings_days_b', 'el_work_earnings_2weeks_b', 'el_work_earnings_month_b', 'el_work_earnings_wrong_7d_b_2', 'el_work_hours_incorrect_7d_2b', 'el_work_transport_costnote_7d_a', 'el_work_transport_costnote_7d_b', 'el_worked_a_intro', 'el_worked_b_intro', 'el_work_transport_mode_b', 'bl_dem_hhemp', 'bl_emp_earn_all_uncd', 'bl_emp_hour_all_uncd', 'bl_emp_history_1', 'bl_emp_history_2', 'bl_emp_history_3', 'bl_emp_history_4', 'bl_emp_history_5', 'bl_emp_history_6', 'bl_emp_wage_all', 'bl_emp_wage_all_uncd', 'bl_emp_earn_all_w', 'bl_emp_hour_all_w', 'bl_emp_hour_all_uncd_w', 'bl_emp_wage_all_w', 'bl_emp_earn_all_uncd_w', 'bl_emp_wage_all_uncd_w', 'bl_search_hour_w', 'bl_everwork1', 'bl_everwork2', 'bl_everwork3']
#   📂 wsdata_signalling_interim_el.dta → ['bl_demo_hh_employed', 'bl_emp_history', 'bl_emp_7d', 'bl_emp_earn_all', 'bl_emp_hour_all', 'bl_search_hour', 'el_emp_m1', 'el_emp_m2', 'el_emp_m3', 'el_emp_7d', 'el_emp_ever', 'el_emp_nbrjobs', 'el_emp_started_7d', 'el_emp_7dtype', 'el_emp_7dtype_wr', 'el_emp_empsize_7d', 'el_emp_transport_7d_mode_a', 'el_emp_7dtrandist', 'el_emp_7dtrancost', 'el_emp_main_paymentperiod', 'el_emp_main_days_lastmonth', 'el_emp_main_weeks_lastmonth', 'el_emp_main_earn_pert_bands', 'el_emp_main_hour_week', 'el_emp_dissatisfied_7d', 'el_emp_future_7d', 'el_emp_recruit_7d', 'el_emped_firm_consent', 'el_emp_earn_all_week_bands', 'el_emp_hour_all', 'el_emp_mtype', 'el_emp_mtype_wr', 'el_emp_started_m', 'el_emp_ended_m_a', 'el_emp_empsize_m', 'el_emp_transport_mode_m_a', 'el_emp_transport_m', 'el_emp_transport_cost_m', 'el_emp_recruit_m', 'el_emp_last_paymentperiod', 'el_emp_last_earn_pert', 'el_emp_last_hour_week', 'el_time_work', 'el_search_hour_7d', 'el_search_hours_m', 'el_search_network_m', 'el_search_workareas_m', 'el_emp_transport_7d_mode_b', 'el_emp_ended_m_b', 'el_emp_transport_mode_m_b', 'el_emp_earnings_incorrect_a', 'el_emp_earnings_incorrect_7d_a', 'el_emp_earnings_incorrect_b', 'el_emp_earnings_incorrect_7d_b', 'el_emp_earnings_hours_a', 'el_emp_earnings_days_a', 'el_emp_earnings_2weeks_a', 'el_emp_earnings_month_a', 'el_emp_earnings_wrong_7d_a_2', 'el_emp_hours_incorrect_7d_2a', 'el_emp_earnings_hours_b', 'el_emp_earnings_days_b', 'el_emp_earnings_2weeks_b', 'el_emp_earnings_month_b', 'el_emp_earnings_wrong_7d_b_2', 'el_emp_hours_incorrect_7d_2b', 'el_emp_transport_costnote_7d_a', 'el_emp_transport_costnote_7d_b', 'el_emped_a_intro', 'el_emped_b_intro', 'el_emp_transport_mode_b', 'bl_dem_hhemp', 'bl_emp_earn_all_uncd', 'bl_emp_hour_all_uncd', 'bl_emp_history_1', 'bl_emp_history_2', 'bl_emp_history_3', 'bl_emp_history_4', 'bl_emp_history_5', 'bl_emp_history_6', 'bl_emp_wage_all', 'bl_emp_wage_all_uncd', 'bl_emp_earn_all_w', 'bl_emp_hour_all_w', 'bl_emp_hour_all_uncd_w', 'bl_emp_wage_all_w', 'bl_emp_earn_all_uncd_w', 'bl_emp_wage_all_uncd_w', 'bl_search_hour_w', 'bl_everwork1', 'bl_everwork2', 'bl_everwork3', 'el_emp_turn3', 'el_emp_turn2', 'el_emp_7dtype_wrperm', 'el_emp_7dtype_none', 'el_emp_7dtype_wrntfix', 'el_emp_7dtype_wrfix', 'el_emp_7dtype_verbfix', 'el_emp_7dtype_verbntfix', 'el_emp_7dtype_self', 'el_emp_7dtype_fam', 'el_emp_7dtype_order', 'el_emp_7dtype_wage', 'el_emp_7dtype_wage_uncd', 'el_emp_7dtype_self_uncd', 'el_emp_7dtype_wr_uncd', 'el_emp_7dtype_wrperm_uncd', 'el_emp_mtype_none', 'el_emp_mtype_wrperm', 'el_emp_mtype_wrfix', 'el_emp_mtype_wrntfix', 'el_emp_mtype_verbfix', 'el_emp_mtype_verbntfix', 'el_emp_mtype_self', 'el_emp_mtype_fam', 'el_emp_mtype_order', 'el_emp_evtype', 'el_emp_evtype_wr', 'el_emp_evtype_none', 'el_emp_evtype_wrperm', 'el_emp_evtype_wrfix', 'el_emp_evtype_wrntfix', 'el_emp_evtype_verbfix', 'el_emp_evtype_verbntfix', 'el_emp_evtype_self', 'el_emp_evtype_fam', 'el_emp_empsize_7d_order', 'el_emp_evtrandist', 'el_emp_evtrancost', 'el_emp_earn_all_week', 'el_emp_main_earn_pert', 'el_emp_earn_all', 'el_emp_earn_ever', 'el_emp_ever_hour_week', 'el_emp_wage_all', 'el_emp_ever_wage', 'el_emp_dissat', 'el_emp_longrun', 'el_emp_dur', 'el_search_type_temp', 'el_search_type_permtemp', 'el_search_hour', 'el_search_apphour', 'el_emp_earn_all_w', 'el_emp_earn_ever_w', 'el_emp_main_hour_week_w', 'el_emp_hour_all_w', 'el_emp_ever_hour_week_w', 'el_emp_wage_all_w', 'el_emp_ever_wage_w', 'el_emp_earn_all_week_w', 'el_search_hour_w', 'el_search_hour_7d_w', 'el_search_apphour_w', 'el_emp_earn_all_uncd', 'el_emp_earn_all_uncd_w', 'el_emp_earn_ever_uncd', 'el_emp_earn_ever_uncd_w', 'el_emp_main_hour_week_uncd', 'el_emp_main_hour_week_uncd_w', 'el_emp_hour_all_uncd', 'el_emp_hour_all_uncd_w', 'el_emp_ever_hour_week_uncd', 'el_emp_ever_hour_week_uncd_w', 'el_emp_wage_all_uncd', 'el_emp_wage_all_uncd_w', 'el_emp_ever_wage_uncd', 'el_emp_ever_wage_uncd_w', 'el_emp_earn_all_week_uncd', 'el ...
#   📂 wsdata_signalling_interim_sms.dta → ['bl_demo_hh_employed', 'bl_emp_history', 'bl_emp_7d', 'bl_emp_earn_all', 'bl_emp_hour_all', 'bl_search_hour', 'el_work_month1_a', 'el_work_month2_a', 'el_work_month3_a', 'el_work_employed_a', 'el_work_started_7d_a', 'el_work_agreement_7d_a', 'el_work_employees_7d_a', 'el_work_transport_7d_mode_a', 'el_work_transport_7d_a', 'el_work_transport_cost_7d_a', 'el_work_payment_a', 'el_work_earnings_7d_a_v1', 'el_work_earnings_7d_a', 'el_work_earnings_7d_a_2', 'el_work_earnings_bands_7d_a', 'el_work_hours_7d_a', 'el_work_dissatisfied_7d_a', 'el_work_future_7d_a', 'el_work_recruited_7d_a', 'el_worked_firm_consent_a', 'el_work_earnings_a_v1', 'el_work_earnings_a', 'el_work_earnings_bands_a', 'el_work_hours_a', 'el_work_agreement_m_a', 'el_work_started_m_a', 'el_work_ended_m_a', 'el_work_employees_m_a', 'el_work_transport_mode_m_a', 'el_work_transport_m_a', 'el_work_transport_cost_m_a', 'el_work_recruited_m_a', 'el_work_payment_m_a', 'el_work_income_a', 'el_work_income_piece_a', 'el_work_hours_7d_2a', 'el_time_work_a', 'el_search_hours_7d_a', 'el_search_network_7d_a', 'el_search_workareas_7d_a', 'el_search_hours_m_a', 'el_search_network_m_a', 'el_search_workareas_m_a', 'el_search_hours_7d_b', 'el_search_network_7d_b', 'el_search_workareas_7d_b', 'el_search_hours_m_b', 'el_search_network_m_b', 'el_search_workareas_m_b', 'el_work_month1_b', 'el_work_month2_b', 'el_work_month3_b', 'el_work_employed_b', 'el_work_agreement_7d_b', 'el_work_started_7d_b', 'el_work_employees_7d_b', 'el_work_transport_7d_mode_b', 'el_work_transport_7d_b', 'el_work_transport_cost_7d_b', 'el_work_payment_b', 'el_work_earnings_7d_b_v1', 'el_work_earnings_7d_b', 'el_work_earnings_7d_b_2', 'el_work_earnings_bands_7d_b', 'el_work_hours_7d_b', 'el_work_dissatisfied_7d_b', 'el_work_future_7d_b', 'el_work_recruited_7d_b', 'el_worked_firm_consent_b', 'el_work_agreement_m_b', 'el_work_started_m_b', 'el_work_ended_m_b', 'el_work_employees_m_b', 'el_work_transport_mode_m_b', 'el_work_transport_m_b', 'el_work_transport_cost_m_b', 'el_work_recruited_m_b', 'el_work_payment_m_b', 'el_work_income_b', 'el_work_income_piece_b', 'el_work_hours_7d_2b', 'el_work_earnings_b_v1', 'el_work_earnings_b', 'el_work_earnings_bands_b', 'el_work_hours_b', 'el_time_work_b', 'el_work_earnings_incorrect_a', 'el_work_earnings_incorrect_7d_a', 'el_work_earnings_incorrect_b', 'el_work_earnings_incorrect_7d_b', 'el_work_earnings_hours_a', 'el_work_earnings_days_a', 'el_work_earnings_2weeks_a', 'el_work_earnings_month_a', 'el_work_earnings_wrong_7d_a_2', 'el_work_hours_incorrect_7d_2a', 'el_work_earnings_hours_b', 'el_work_earnings_days_b', 'el_work_earnings_2weeks_b', 'el_work_earnings_month_b', 'el_work_earnings_wrong_7d_b_2', 'el_work_hours_incorrect_7d_2b', 'el_work_transport_costnote_7d_a', 'el_work_transport_costnote_7d_b', 'el_worked_a_intro', 'el_worked_b_intro', 'el_work_transport_mode_b', 'bl_dem_hhemp', 'bl_emp_earn_all_uncd', 'bl_emp_hour_all_uncd', 'bl_emp_history_1', 'bl_emp_history_2', 'bl_emp_history_3', 'bl_emp_history_4', 'bl_emp_history_5', 'bl_emp_history_6', 'bl_emp_wage_all', 'bl_emp_wage_all_uncd', 'bl_emp_earn_all_w', 'bl_emp_hour_all_w', 'bl_emp_hour_all_uncd_w', 'bl_emp_wage_all_w', 'bl_emp_earn_all_uncd_w', 'bl_emp_wage_all_uncd_w', 'bl_search_hour_w', 'bl_everwork1', 'bl_everwork2', 'bl_everwork3']
#   📂 lmdsa-2016-1.0-stata11.dta → ['Q313TIMEUNEMPLOY', 'Q416NRWORKERS', 'Unempl_Status', 'infempl', 'long_term_unempl', 'underempl']
#   📂 lmdsa-2017-1.0-stata11.dta → ['Q313TIMEUNEMPLOY', 'Q416NRWORKERS', 'Unempl_Status', 'infempl', 'long_term_unempl', 'underempl']
#
# ▶ Johnson_2020_Data 탐색 중...
#   📂 osha_inspection_march2017_with_latlong.dta → ['estabid_osha']
#   📂 osha_violations_march2017.dta → ['current_penalty', 'initial_penalty', 'fta_penalty', 'hist_penalty']
#   📂 prs_with_news_coverage.dta → ['press_release_penalty']
#
# ▶ Azoulay_et_al_2019_Data 탐색 중...
# C:\Users\starw\AppData\Local\Temp\ipykernel_23256\272477706.py:29: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   df = pd.read_stata(f, convert_categoricals=False)
#   📂 aer_2016-1574_replication_set.dta → ['nb_pmra_ncoauth', 'nbgrants_ncoauth', 'nb_pmra_qrt1_ncoauth', 'nb_pmra_qrt2_ncoauth', 'nb_pmra_qrt3_ncoauth', 'nb_pmra_75to95_ncoauth', 'nb_pmra_95to99_ncoauth', 'nb_pmra_abv99_ncoauth', 'nb_pmra_hi_prxmt_crdnl_ncoauth', 'nb_pmra_lo_prxmt_crdnl_ncoauth', 'nb_pmra_hi_prxmt_ordnl_ncoauth', 'nb_pmra_lo_prxmt_ordnl_ncoauth', 'nb_pmra_yciteinfield_ncoauth', 'nb_pmra_nciteinfield_ncoauth', 'nb_pmra_ycitethestar_ncoauth', 'nb_pmra_ncitethestar_ncoauth', 'nb_pmra_lo_refs_vntg_ncoauth', 'nb_pmra_hi_refs_vntg_ncoauth', 'nb_pmra_lo_2wy_mesh_vntg_ncoauth', 'nb_pmra_hi_2wy_mesh_vntg_ncoauth', 'nb_pmra_prox_0_ncoauth', 'nb_pmra_prox_belowmed_ncoauth', 'nb_pmra_prox_50to55_ncoauth', 'nb_pmra_prox_55to60_ncoauth', 'nb_pmra_prox_60to65_ncoauth', 'nb_pmra_prox_65to70_ncoauth', 'nb_pmra_prox_70to75_ncoauth', 'nb_pmra_prox_75to80_ncoauth', 'nb_pmra_prox_80to85_ncoauth', 'nb_pmra_prox_85to90_ncoauth', 'nb_pmra_prox_90to95_ncoauth', 'nb_pmra_prox_95to99_ncoauth', 'nb_pmra_prox_above99_ncoauth']
#   📂 aer_2016-1574_srce_rltd_pairs_replication_set.dta → ['prox']
#
# ▶ Cao_and_Chen_2022_Data 탐색 중...
#
# ▶ Moretti_2021_Data 탐색 중...
#   📂 patent_assignees.dta → ['org_type', 'city', 'country', 'country_code']
#   📂 patent_citations.dta → ['cite_from_patent_gyr', 'cite_to_patent_gyr']
#   📂 patent_cite_counts.dta → ['grant_year']
#   📂 patent_inventors.dta → ['suffix', 'city', 'country', 'country_code']
#   📂 tva1.dta → ['state_county00', 'county_county00', 'name_county00', 'level_county00', 'statefip_county00', 'counfip_county00', 'level2_county00', 'metrofip_county00', 'pmsafip_county00', 'stcode_county00', 'countype_county00', 'b1_lnd01_county00', 'b1_pop01_county00', 'b1_pop02_county00', 'b1_pop03_county00', 'b1_pop04_county00', 'b1_pop05_county00', 'b1_pop06_county00', 'b1_pop07_county00', 'b1_pop08_county00', 'b1_pop09_county00', 'b1_pop10_county00', 'b1_pop11_county00', 'b1_pop12_county00', 'b1_pop13_county00', 'b1_pop14_county00', 'b1_pop15_county00', 'b1_pop16_county00', 'b2_pop01_county00', 'b2_age01_county00', 'b2_age02_county00', 'b2_age03_county00', 'b2_age04_county00', 'b2_age05_county00', 'b2_age06_county00', 'b2_age07_county00', 'b2_age08_county00', 'b2_age09_county00', 'b2_age10_county00', 'b2_age11_county00', 'b2_age12_county00', 'b2_age13_county00', 'b2_age14_county00', 'b2_age15_county00', 'b2_age16_county00', 'b2_age17_county00', 'b2_pop02_county00', 'b2_pop03_county00', 'b2_pop04_county00', 'b2_pop05_county00', 'b2_pop06_county00', 'b2_pop07_county00', 'b2_pop08_county00', 'b2_pop09_county00', 'b2_pop10_county00', 'b2_pop11_county00', 'b2_pop12_county00', 'b2_pop13_county00', 'b2_pop14_county00', 'b2_pop15_county00', 'b2_pop16_county00', 'b2_pop17_county00', 'b2_pop18_county00', 'b3_pop01_county00', 'b3_pop02_county00', 'b3_hsd01_county00', 'b3_hsd02_county00', 'b3_hsd03_county00', 'b3_hsd04_county00', 'b3_hsd05_county00', 'b3_hsd06_county00', 'b3_hsd07_county00', 'b3_hsd08_county00', 'b3_hsd09_county00', 'b3_hsd10_county00', 'b3_hsd11_county00', 'b3_hsd12_county00', 'b3_hsd13_county00', 'b3_hsd14_county00', 'b3_hsd15_county00', 'b3_hsd16_county00', 'b3_hsd17_county00', 'b3_hsd18_county00', 'b3_hsd19_county00', 'b3_hsd20_county00', 'b3_hsd21_county00', 'b3_hsd22_county00', 'b3_hsd23_county00', 'b4_vst01_county00', 'b4_vst02_county00', 'b4_vst03_county00', 'b4_vst04_county00', 'b4_vst05_county00', 'b4_vst06_county00', 'b4_vst07_county00', 'b4_hlt01_county00', 'b4_hlt02_county00', 'b4_hlt03_county00', 'b4_hlt04_county00', 'b4_hlt05_county00', 'b4_hlt06_county00', 'b4_hlt07_county00', 'b4_hlt08_county00', 'b4_hlt09_county00', 'b5_edc01_county00', 'b5_edc02_county00', 'b5_edc03_county00', 'b5_edc04_county00', 'b5_edc05_county00', 'b5_edc06_county00', 'b5_edc07_county00', 'b5_edc08_county00', 'b5_inc01_county00', 'b5_inc02_county00', 'b5_inc03_county00', 'b5_pov01_county00', 'b5_pov02_county00', 'b5_pov03_county00', 'b5_pov04_county00', 'b5_pov05_county00', 'b6_crm01_county00', 'b6_crm02_county00', 'b6_crm03_county00', 'b6_crm04_county00', 'b6_crm05_county00', 'b6_crm06_county00', 'b6_crm07_county00', 'b6_crm08_county00', 'b6_hsg01_county00', 'b6_hsg02_county00', 'b6_hsg03_county00', 'b6_hsg04_county00', 'b6_hsg05_county00', 'b6_bld01_county00', 'b6_bld02_county00', 'b6_bld03_county00', 'b6_bld04_county00', 'b6_bld05_county00', 'b6_bld06_county00', 'b7_clf01_county00', 'b7_clf02_county00', 'b7_clf03_county00', 'b7_clf04_county00', 'b7_clf05_county00', 'b7_bus01_county00', 'b7_bus02_county00', 'b7_bus03_county00', 'b7_bus04_county00', 'b7_bus05_county00', 'b7_bus06_county00', 'b7_bus07_county00', 'b7_bus08_county00', 'b7_bus09_county00', 'b7_bus10_county00', 'b8_pie01_county00', 'b8_pie02_county00', 'b8_pie03_county00', 'b8_pie04_county00', 'b8_pie05_county00', 'b8_pie06_county00', 'b8_pie07_county00', 'b8_pie08_county00', 'b8_pie09_county00', 'b8_pie10_county00', 'b8_pie11_county00', 'b8_pie12_county00', 'b8_pie13_county00', 'b8_pie14_county00', 'b8_pie15_county00', 'b8_pie16_county00', 'b8_pie17_county00', 'b8_pie18_county00', 'b8_pie19_county00', 'b8_pie20_county00', 'b8_pie21_county00', 'b8_pie22_county00', 'b8_man01_county00', 'b8_man02_county00', 'b8_man03_county00', 'b9_man01_county00', 'b9_man02_county00', 'b9_man03_county00', 'b9_man04_county00', 'b9_man05_county00', 'b9_man06_county00', 'b9_man07_county00', 'b9_man08_county00', 'b9_man09_county00', 'b9_wat01_county00', 'b9_wat02_county00', 'b9_wat03_co ...
#
# [DONE] 결과 저장 완료 → C:\Users\starw\OneDrive\바탕 화면\dta\remaining5_manual_search.xlsx
